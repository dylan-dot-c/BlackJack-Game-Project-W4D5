# %% [markdown]
# ## Python Blackjack
# For this project you will make a Blackjack game using Python. Click <a href="http://www.hitorstand.net/strategy.php">here</a> to familiarize yourself with the the rules of the game. You won't be implementing every rule "down to the letter" with the game, but we will doing a simpler version of the game. This assignment will be given to further test your knowledge on object-oriented programming concepts.
#
# ### Rules:
#
# `1. ` The game will have two players: the Dealer and the Player. The game will start off with a deck of 52 cards. The 52 cards will consist of 4 different suits: Clubs, Diamonds, Hearts and Spades. For each suit, there will be cards numbered 1 through 13. <br>
# **Note: No wildcards will be used in the program**
#
# `2. ` When the game begins, the dealer will shuffle the deck of cards, making them randomized. After the dealer shuffles, it will deal the player 2 cards and will deal itself 2 cards from. The Player should be able to see both of their own cards, but should only be able to see one of the Dealer's cards.
#
# `3. ` The objective of the game is for the Player to count their cards after they're dealt. If they're not satisfied with the number, they have the ability to 'Hit'. A hit allows the dealer to deal the Player one additional card. The Player can hit as many times as they'd like as long as they don't 'Bust'. A bust is when the Player is dealt cards that total more than 21.
#
# `4. ` If the dealer deals the Player cards equal to 21 on the **first** deal, the Player wins. This is referred to as Blackjack. Blackjack is **NOT** the same as getting cards that equal up to 21 after the first deal. Blackjack can only be attained on the first deal.
#
# `5. ` The Player will never see the Dealer's hand until the Player chooses to 'stand'. A Stand is when the player tells the dealer to not deal it anymore cards. Once the player chooses to Stand, the Player and the Dealer will compare their hands. Whoever has the higher number wins. Keep in mind that the Dealer can also bust.

# %% [markdown]
# <h1>BlackJack Game</h1>
#
# <h2>Step 1</h2>
#
# <p>Create classes for The game <b><i>BlackJack</i></b></p>
#
# <input type="text">

# %%
# card class
# deck class
from random import shuffle

class BlackJack:
    def __init__(self):
        self.player = Player()
        self.dealer = Dealer()
        
    def giveHand(self, person):
        person.hand = [self.deck.deckCards.pop(), self.deck.deckCards.pop()]
        if type(person) == Player:
            print("Your current hand is: ", person.hand)
            print("Your total is", person.getsum())
        else:
            print("Dealer Hand is")
            print(f"[HIDDEN, {person.hand[-1]}]")
#         print(person.hand)
#         print(len(self.deck))
        
    def hit(self, person):
        card = self.deck.deckCards.pop()
        print(card)
        person.hand.append(card)
        
    def newRound(self):
        self.deck = Deck()
        self.giveHand(self.player)
        self.giveHand(self.dealer)
        
class Human:
    def __init__(self):
        self.hand = []
        
    def getsum(self):
        values = [card.value for card in self.hand]
        return sum(values)  


class Player(Human):
    def __init__(self, total=500):
        super().__init__()
        self.name = input("Enter name please: ").strip().title()
        self.total = total
        
    def addTotal(self, bet):
        self.total += bet
        
    def reduceTotal(self, bet):
        self.total -= bet
#     def getCardTotal(self):
        

class Dealer(Human):
    def __init__(self):
        super().__init__()
#         pass
# random.
class Card:
    face_cards = {
        11: "Jack",
        12: "Queen",
        13: "King",
        1: "Ace"
    }
    def __init__(self, suit:str, value: int):
        self.suit = suit
        self.value = value if value not in Card.face_cards else 10
        self.name = Card.face_cards.get(value, str(self.value))
        if value == 1:
            self.value = 11
            
    def __str__(self):
        return f"{self.name} of {self.suit}"
    
    def __repr__(self):
        return f"<Card | {self.name} {self.suit}>"
class Deck:
    suits = ["Clubs", "Spades", "Hearts", "Diamonds"]
    
    def generateDeck(self):
        deck = [Card(suit, value) for suit in Deck.suits for value in range(1,14)]
        shuffle(deck)
#         print(deck, len(deck))
        return deck
    
    def __init__(self):
        self.deckCards = self.generateDeck()
        
    def __len__(self):
        return len(self.deckCards)
#     def __get
# card = Card("Clubs", 1)
# print(card)
# deck = Deck().deck
# shuffle(deck)
# print(deck)
# deck.pop()

# for c in deck.deck:
#     print(c)

from time import sleep
game = BlackJack()
rounds = 0 
def getOptions():
    options = ["Hit", "Stand"]
    print("="*40)
    [print(f"{i+1} {options[i]}") for i in range(len(options))]
    choice = input("Enter your Choice: ").strip().title()
    if choice in options:
        return choice
    else:
        return getOptions()
# while True:
total = game.player.total
choice1 = "Deal"
while choice1 == "Deal" and total > 0:
#     game.newRound()
    rounds += 1
    bet = abs(int(input(f"How much you wanna bet? Total is {game.player.total}:: ")))
    if bet > total:
        bet = total
    game.newRound()
    print(f"ROUND: {rounds}")
    if round == 1:
        if game.player.getSum() == 21:
            print("BlackJack!! Player has won!!")
 
    winner =  False
    while not winner:
        rounds+=1
        dealer = game.dealer.getsum()
        player = game.player.getsum()

        choice = getOptions()
        if choice == "Hit":
            print("HIT")
    #         add a new card
            game.hit(game.player)
            playerSum = game.player.getsum()
            if playerSum == 21:
                print("Player has won!")
                game.player.addTotal(bet)
                break
            elif playerSum > 21:
                print("Player Busted! You lose!!")
                game.player.reduceTotal(bet)
                winner = game.dealer
            print("Total is: ", (game.player.getsum()))
            
            
        else:
            dealer = game.dealer.getsum()
            player = game.player.getsum()
            
            while dealer < 17:
                sleep(2)
                game.hit(game.dealer)
                dealer = game.dealer.getsum()
                print(game.dealer.hand, "Total is", dealer)
            if dealer > 21:
                print("Dealer Busted! You criminal")
                winner = game.player
                print("Dealer has", dealer)
                game.player.addTotal(bet)
                break
            
            if dealer > player:
                print("Dealer WON!!")
                winner = game.dealer
                game.player.reduceTotal()
                break
            elif dealer < player:
                print("Player has won!")
                game.player.addTotal(bet)
                break
            else:
                print("No winner")
                winner = "false"
                
    total = game.player.total
    choice1 = input("What do you wanna do now? DEAL OR Cashout: ").strip().title()
#     game.newRound()
    rounds = 0
    
print("Thanks for playing!")
print("Your total is", game.player.total)
